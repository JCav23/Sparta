# %% [markdown]
# # Video Game Sales

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
sales_data = pd.read_csv("./vgsales.csv")
sales_data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # Introduction
#
# This report details the sales data for 'Video Game Sales' across the different geographical region. Outlined below are the steps taken to clean the data, followed by various graphical representations of various insights drawn from the data

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Check for Duplicate Records

# %%
duplicated_rows = sales_data[sales_data.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %% [markdown]
# ### Data doesn't contain any duplicated records

# %% [markdown]
# ### Check for Missing Values within the data

# %%
sales_data.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
sales_hm = sns.heatmap(sales_data.isnull())

# %%
percent_null = (271 / 16598) * 100
print(percent_null)
# Out:
# 1.6327268345583803

# %% [markdown]
# ### Null values for Year are less than 2% so drop the entries

# %%
sales_data.dropna(how='any', axis=0, inplace=True)
sales_data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Top Ten Publishers by their Total Global Sales

# %%
publisher_totals = sales_data.groupby(['Publisher'])['Global_Sales'].sum().sort_values(ascending = False)
top_ten = publisher_totals.head(10)
publisher_totals
# Out:
# Publisher
# Nintendo                       1784.43
# Electronic Arts                1093.39
# Activision                      721.41
# Sony Computer Entertainment     607.28
# Ubisoft                         473.54
#                                 ...
# Epic Games                        0.01
# Paradox Development               0.01
# Rain Games                        0.01
# Ascaron Entertainment             0.01
# Commseed                          0.01
# Name: Global_Sales, Length: 576, dtype: float64

# %%
top_ten.plot.bar(x='Publisher', y='Global_Sales', color=['red', 'blue', 'yellow', 'green', 'purple', 'pink', 'black', 'orange', 'grey', 'brown'], label='Publisher', title = 'Top Ten Publishers by Total Global Sales')
# Out:
# <Axes: title={'center': 'Top Ten Publishers by Total Global Sales'}, xlabel='Publisher'>

# %% [markdown]
# ## Top Ten Game Sales By Region

# %%
top_ten_games = pd.DataFrame({'Name':sales_data['Name'], 'Platform':sales_data['Platform'], 'NA_Sales':sales_data['NA_Sales'], 'EU_Sales':sales_data['EU_Sales'], 'JP_Sales':sales_data['JP_Sales'], 'Other_Sales':sales_data['Other_Sales'], 'Global_Sales':sales_data['Global_Sales']})
top_ten_games
# Out:
#                                                    Name Platform  NA_Sales  \
# 0                                            Wii Sports      Wii     41.49
# 1                                     Super Mario Bros.      NES     29.08
# 2                                        Mario Kart Wii      Wii     15.85
# 3                                     Wii Sports Resort      Wii     15.75
# 4                              Pokemon Red/Pokemon Blue       GB     11.27
# ...                                                 ...      ...       ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA      0.01
# 16594                     Men in Black II: Alien Escape       GC      0.01
# 16595  SCORE International Baja 1000: The Official Game      PS2      0.00
# 16596                                        Know How 2       DS      0.00
# 16597                                  Spirits & Spells      GBA      0.01
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %% [markdown]
# ### North America

# %%
sns.barplot(top_ten_games.head(10), x='NA_Sales', y='Name').set(title='Top Ten Best Selling Games - North America')
# Out:
# [Text(0.5, 1.0, 'Top Ten Best Selling Games - North America')]

# %% [markdown]
# ### Europe

# %%
sns.barplot(top_ten_games.head(10), x='EU_Sales', y='Name').set(title='Top Ten Best Selling Games - Europe')
# Out:
# [Text(0.5, 1.0, 'Top Ten Best Selling Games - Europe')]

# %% [markdown]
# ### Japan

# %%
sns.barplot(top_ten_games.head(10), x='JP_Sales', y='Name').set(title='Top Ten Best Selling Games - Japan')
# Out:
# [Text(0.5, 1.0, 'Top Ten Best Selling Games - Japan')]

# %% [markdown]
# ### Rest of The World

# %%
sns.barplot(top_ten_games.head(10), x='Other_Sales', y='Name').set(title='Top Ten Best Selling Games - Rest of The World')
# Out:
# [Text(0.5, 1.0, 'Top Ten Best Selling Games - Rest of The World')]

# %% [markdown]
# ## Total Region Sales

# %%
region = pd.DataFrame({'North America':sales_data['NA_Sales'], 'Europe':sales_data['EU_Sales'], 'Japan':sales_data['JP_Sales'], 'Rest of The World':sales_data['Other_Sales']})
labels = ['North America', 'Europe', 'Japan', 'Rest of The World']
colors = sns.color_palette('colorblind')

plt.pie(region.sum(), labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Total Global Sales by Region')
# Out:
# Text(0.5, 1.0, 'Total Global Sales by Region')
